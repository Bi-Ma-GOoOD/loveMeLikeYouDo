# %% [markdown]
# ## Before start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
'''You can use prompt nvidia-smi in anaconda command prompt to check CUDA availability and GPU availability'''
# Out:
# CUDA Available: True

# %% [markdown]
# ## Set up the Environment

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.75  Python-3.10.15 torch-2.6.0.dev20241206+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# Setup complete  (16 CPUs, 15.9 GB RAM, 492.5/931.5 GB disk)

# %%
# Import Libraries
import ultralytics
from ultralytics import YOLO

import cv2
from google.colab.patches import cv2_imshow

from PIL import Image
import numpy as np

import pandas as pd

import os

import cv2
from imageio import imread

import imageio.v2 as imageio

import matplotlib.pyplot as plt

import torch
from torchinfo import summary

# %matplotlib inline

# %% [markdown]
# ### Set your dataset location

# %%
# Set HOME to your desired directory in loacl device
HOME = '/content/drive/MyDrive/DeepLearning/FinalProject'

# Create the directory if it doesn't exist
if not os.path.exists(HOME):
  os.makedirs(HOME)

print(HOME)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DeepLearning/FinalProject

# %%
def createDirectory(path):
  if not os.path.exists(path):
    os.makedirs(path)

# %% [markdown]
# ## Play Picture

# %% [markdown]
# **NOTE**
# *   Play picture is like you want to try a picture to test with pretained model (YOLO - V08).
# *   If you run the third cell of Play Picture code will automically create PlayPicture directory in your google drive

# %% [markdown]
# When you run the cell below google colab will automically create {HOME}/PlayPicture.

# %%
createDirectory(f"{HOME}/PlayPicture")

image_path = "/content/drive/MyDrive/DeepLearning/FinalProject/PlayPicture/❤.png"

print(">> Using the Test My Love Image: {}".format(image_path))
img = imageio.imread(image_path)
plt.imshow(img)
# Out:
# >> Using the Test My Love Image: /content/drive/MyDrive/DeepLearning/FinalProject/PlayPicture/❤.png

# %% [markdown]
# ## YOLOv8 - Pretrained Model

# %%
# Define a YOLO model and print the model summary
# Load the model
model = YOLO('yolo11n.pt')

# # Create a dummy input tensor (batch_size=1, channels=3, height=640, width=640)
# dummy_input = torch.randn(10, 3, 640, 640)

# # Get model summary (like Keras)
# summary(model.model, input_size=(10, 3, 640, 640))

# Model summary
model.info()
# Out:
# YOLO11n summary: 319 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
# (319, 2624080, 0, 6.614336)
